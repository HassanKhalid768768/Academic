# %%
import pandas as pd

# %%
df=pd.read_csv('/content/brca_cancer.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             gene_id gene_name       gene_type  unstranded  \
# 0           4  ENSG00000000003.15    TSPAN6  protein_coding        5175
# 1           5   ENSG00000000005.6      TNMD  protein_coding          85
# 2           6  ENSG00000000419.13      DPM1  protein_coding        2406
# 3           7  ENSG00000000457.14     SCYL3  protein_coding        2222
# 4           8  ENSG00000000460.17  C1orf112  protein_coding         476
#
#    stranded_first  stranded_second  tpm_unstranded  fpkm_unstranded  \
# 0            2582             2594         58.4397          16.4625
# 1              52               33          2.9499           0.8310
# 2            1194             1212        102.1078          28.7639
# 3            1629             1631         16.5362           4.6583
# 4             808              782          4.0842           1.1505
#
#    fpkm_uq_unstranded  class
# 0             16.0650      0
# 1              0.8109      0
# 2             28.0692      0
# 3              4.5458      0
# 4              1.1227      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121320 entries, 0 to 121319
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          121320 non-null  int64
#  1   gene_id             121320 non-null  object
#  2   gene_name           121320 non-null  object
#  3   gene_type           121320 non-null  object
#  4   unstranded          121320 non-null  int64
#  5   stranded_first      121320 non-null  int64
#  6   stranded_second     121320 non-null  int64
#  7   tpm_unstranded      121320 non-null  float64
#  8   fpkm_unstranded     121320 non-null  float64
#  9   fpkm_uq_unstranded  121320 non-null  float64
#  10  class               121320 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 10.2+ MB

# %%
dfe=df.loc[:,['gene_name','tpm_unstranded','class']]

# %%
dfe.head()
# Out:
#   gene_name  tpm_unstranded  class
# 0    TSPAN6         58.4397      0
# 1      TNMD          2.9499      0
# 2      DPM1        102.1078      0
# 3     SCYL3         16.5362      0
# 4  C1orf112          4.0842      0

# %%
len(dfe['gene_name'].unique()) # Total number of unique genes in an organ
# Out:
# 59427

# %%
dfe['gene_name'].value_counts()
# Out:
# gene_name
# Y_RNA          1512
# Metazoa_SRP     340
# U3              100
# U6               66
# SNORA70          54
#                ...
# CYS1              2
# PLPP6             2
# KLRC2             2
# KLRC3             2
# AP006621.6        2
# Name: count, Length: 59427, dtype: int64

# %%
dfe[dfe['gene_name']=='PIK3CA']  # PIK3CA Gene
# Out:
#       gene_name  tpm_unstranded  class
# 5204     PIK3CA         10.6744      0
# 65864    PIK3CA          6.7967      1

# %%
dfe[dfe['gene_name']=='TP53']
# Out:
#       gene_name  tpm_unstranded  class
# 8124       TP53         55.8894      0
# 68784      TP53         42.4685      1

# %%
dfe[dfe['gene_name']=='BRCA1']
# Out:
#       gene_name  tpm_unstranded  class
# 310       BRCA1          4.8549      0
# 60970     BRCA1          3.0269      1

# %%
dfe[dfe['gene_name']=='NF1']
# Out:
#       gene_name  tpm_unstranded  class
# 17196       NF1         19.8343      0
# 77856       NF1          7.0352      1

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
# Encode labels in column 'species'
dfe['gene_name']=encoder.fit_transform(dfe['gene_name'])

# %%
from sklearn.model_selection import train_test_split

# %%
y=dfe['class']
X=dfe.drop(['class'],axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predictions=dtree.predict(X_test)

# %%
print(classification_report(y_test,y_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.38      0.41      0.39     18210
#            1       0.36      0.33      0.34     18186
#
#     accuracy                           0.37     36396
#    macro avg       0.37      0.37      0.37     36396
# weighted avg       0.37      0.37      0.37     36396
