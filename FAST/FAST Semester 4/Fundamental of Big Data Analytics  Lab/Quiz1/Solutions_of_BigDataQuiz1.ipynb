# %% [markdown]
# **Big Data Lab - Quiz-1 - Spring 2023** <br>
# Please note:
# - Total marks are 10
# - No internet or helping material is allowed
# - You can use Google colab (only if Jupyter is not installed on your system
# - Please submit your ipynb mfile on Google Classroom
# - Add #Roll_Number as filename and download the .ipynb file, submit the file. No link sharing is allowed.
# - The allowed time is **30 minutes**

# %% [markdown]
# All the Questions are to be solved. <br>
# **Solve the following problems (Marks = 10)** <br>

# %% [markdown]
# **Part I: Find the matching substrings (Marks=2)** <br>

# %% [markdown]
# Write a function get_substring_positions() that accepts two strings as arguments. Return the **number of the positions** where they contain the same substring of length 2. For example, **"docatzz"** and **"dobatz"** should yield 3, since the "do", "at", and "tz" substrings appear in the same place in both strings.

# %%
#Part 1 
def get_substring_positions(str1 , str2):
    len1 = len(str1)
    len2 = len(str2)
    
    count = 0
    for i in range(len1):
        for j in range(len2):
            if str1[i] == str2[j] and i < (len1 -1) and j < (len2 -1):
                if str1[i+1] == str2[j+1]:
                    count += 1
    return count
count = get_substring_positions("subsubsub" , "")
print("Total same substrings:- " , count)

# %% [markdown]
# **Part II: Find all tuples divisible by K (Marks = 1.5)**

# %% [markdown]
# Given a list of tuples. The task is to extract all tuples which have all elements divisible by K.
# <br>
# Input : test_list = [(6, 24, 12), (60, 12, 6), (12, 18, 21)] <br>   K = 6 <br>
# Output : [(6, 24, 12), (60, 12, 6)] <br>
# Explanation : Both tuples have all elements multiple of 6 <br>

# %%
test_list = [(6, 24, 12), (60, 12, 6), (12, 18, 21)]
k = 6
k_tuples=[] #list to store tuples which have all elements divisible by K

for i in test_list:
    if(i[0]%k==0 and i[1]%k==0 and i[2]%k==0):
        k_tuples.append((i[0],i[1],i[2]))

for i in k_tuples: #print list of tuples which have all elements divisible by K
    print(i)
# Out:
# (6, 24, 12)
# (60, 12, 6)

# %% [markdown]
# **Part III: Find if there are common elements between two lists (Marks=1.5)**

# %% [markdown]
# Given two lists a, b. Check if two lists have at least one element common in them. <br>
# Input : a = [1, 2, 3, 4, 5] , b = [5, 6, 7, 8, 9] <br>
# Output : True <br>
# **Note:** You are not allowed to use Loop (of any type)

# %%
### write your code here ###
a = [1, 2, 3, 4, 5]
b = [5, 6, 7, 8, 9]

if len(set(a) & set(b)) > 0:
    print('True')
else:
    print('False')
# Out:
# True

# %% [markdown]
# **Part IV: Analyze the dataset (Marks=5)**
# <br>
# Dataset is attached. *googleplaystore.csv*

# %% [markdown]
# **Part A: Find the count of apps for each category (Marks= 1.5)**

# %%
### write your code here use only matplotlib, pandas ###
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('googleplaystore.csv')
df1 = df.iloc[:, 0:2]
df1.groupby('Category')['App'].nunique().plot(kind='bar')

# %% [markdown]
# **Part B: List the names of top 10 most installed applications (Marks=1.5)**

# %%
### Write your code here
df['Installs'] = df['Installs'].replace(',','')
df['Installs'] = df['Installs'].str[:-1]
df2 = df.sort_values('Installs',ascending=False)
df2.head(10)
# Out:
#                                            App            Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                 1.9    19.0
# 1759                              Temple Run 2                GAME     4.3
# 3711                                 MX Player       VIDEO_PLAYERS     4.5
# 2610                                  Snapchat              SOCIAL     4.0
# 2603                                  Snapchat              SOCIAL     4.0
# 342                            Viber Messenger       COMMUNICATION     4.3
# 3739                                   Twitter  NEWS_AND_MAGAZINES     4.3
# 347              imo free video calls and chat       COMMUNICATION     4.3
# 2550                                  Snapchat              SOCIAL     4.0
# 2546                             Facebook Lite              SOCIAL     4.3
#
#         Reviews                Size    Installs  Type     Price  \
# 10472      3.0M              1,000+          Fr     0  Everyone
# 1759    8118937                 62M  500,000,00  Free         0
# 3711    6474672  Varies with device  500,000,00  Free         0
# 2610   17015352  Varies with device  500,000,00  Free         0
# 2603   17014705  Varies with device  500,000,00  Free         0
# 342    11334799  Varies with device  500,000,00  Free         0
# 3739   11667403  Varies with device  500,000,00  Free         0
# 347     4785892                 11M  500,000,00  Free         0
# 2550   17014787  Varies with device  500,000,00  Free         0
# 2546    8606259  Varies with device  500,000,00  Free         0
#
#       Content Rating                   Genres    Last Updated  \
# 10472            NaN        February 11, 2018          1.0.19
# 1759        Everyone                   Action    July 5, 2018
# 3711        Everyone  Video Players & Editors  August 6, 2018
# 2610            Teen                   Social   July 30, 2018
# 2603            Teen                   Social   July 30, 2018
# 342         Everyone            Communication   July 18, 2018
# 3739      Mature 17+         News & Magazines  August 6, 2018
# 347         Everyone            Communication    June 8, 2018
# 2550            Teen                   Social   July 30, 2018
# 2546            Teen                   Social  August 1, 2018
#
#               Current Ver         Android Ver
# 10472          4.0 and up                 NaN
# 1759               1.49.1          4.0 and up
# 3711   Varies with device  Varies with device
# 2610   Varies with device  Varies with device
# 2603   Varies with device  Varies with device
# 342    Varies with device  Varies with device
# 3739   Varies with device  Varies with device
# 347      9.8.000000010501          4.0 and up
# 2550   Varies with device  Varies with device
# 2546   Varies with device  Varies with device

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **Part C: (Marks =  2)** <br> List the names of top 10 most installed applications (in both paid and free versions) and plot them. There should be two plots, one for free apps and second for paid apps

# %%
### Write your code here
#find top 1o installed apps for both category
freeapps = df.query('Type == "Free"')
paidapps =df.query('Type == "Paid"')
freeapps1 = freeapps.sort_values('Installs',ascending=False)
paidapps1 = paidapps.sort_values('Installs',ascending=False)
freeapps2 = freeapps1.head(10)
paidapps2 = paidapps1.head(10)
import matplotlib.pyplot as plt
fig = plt.figure()
x = freeapps2['App']
y = freeapps2['Installs']
plt.scatter(x,y)
plt.show()

# %% [markdown]
# **Sample matplotlib code**

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students)
plt.show()
